# %% [markdown]
# <a href="https://colab.research.google.com/github/Maisha1714/Pandas_in_ML/blob/main/Pandas_for_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **List,Dictionary to DataFrame**

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
car = ['Lemborgini','Ferrari','Audi','BMW','Tesla']
car
# Out:
# ['Lemborgini', 'Ferrari', 'Audi', 'BMW', 'Tesla']

# %%
df = pd.DataFrame(car)
df
# Out:
#             0
# 0  Lemborgini
# 1     Ferrari
# 2        Audi
# 3         BMW
# 4       Tesla

# %%
row , col = df.shape
print(row)
print(col)
# Out:
# 5
# 1

# %%
df = pd.DataFrame(car, columns = ['Dream_Car'])
df
# Out:
#     Dream_Car
# 0  Lemborgini
# 1     Ferrari
# 2        Audi
# 3         BMW
# 4       Tesla

# %%
df = pd.DataFrame(car, columns = ['Dream_Car'],index = ['car1','car2','car3','car4','car5'])
df
# Out:
#        Dream_Car
# car1  Lemborgini
# car2     Ferrari
# car3        Audi
# car4         BMW
# car5       Tesla

# %%
cars = ['Toyota','Honda','Range Rover']
df = pd.DataFrame(zip(car,cars),columns = ['Dream_Car','Dream_Car_2'])
df
# Out:
#     Dream_Car  Dream_Car_2
# 0  Lemborgini       Toyota
# 1     Ferrari        Honda
# 2        Audi  Range Rover

# %%
df
# Out:
#     Dream_Car  Dream_Car_2
# 0  Lemborgini       Toyota
# 1     Ferrari        Honda
# 2        Audi  Range Rover

# %% [markdown]
# # **2D DataFrame**

# %%
carss = [['Moto','Mercedes'],['Yamana','Honda'],['Toyota','Range Rover']]
type(carss)
# Out:
# list

# %%
df1 = pd.DataFrame(carss)
df1
# Out:
#         0            1
# 0    Moto     Mercedes
# 1  Yamana        Honda
# 2  Toyota  Range Rover

# %%
dict1 = {
    'car_1' : cars,
    'car_2' : carss
}
dict1
# Out:
# {'car_1': ['Toyota', 'Honda', 'Range Rover'],
#  'car_2': [['Moto', 'Mercedes'],
#   ['Yamana', 'Honda'],
#   ['Toyota', 'Range Rover']]}

# %%
df3 = pd.DataFrame(dict1)
df3
# Out:
#          car_1                  car_2
# 0       Toyota       [Moto, Mercedes]
# 1        Honda        [Yamana, Honda]
# 2  Range Rover  [Toyota, Range Rover]

# %%
df4 = pd.read_csv('/content/Screen Timing- Sheet2 (1).csv')
df4
# Out:
#                                           Age  0_to_1_hour  2_to_3_hours  \
# 0    Parent of a kid Younger than 5 years old           25            51
# 1          Parent of a kid 5 to 12 years old            19            47
# 2          Parent of a kid 13 to 17 years old            8            38
# 3                              Total Under 18           52           136
# 4                Parent of a kid 18 or older            63            77
# 5                                       Total          115           213
# 6   Parent of a kid Younger than 5 years old            50            76
# 7          Parent of a kid 5 to 12 years old            53           133
# 8          Parent of a kid 13 to 17 years old           21           110
# 9                              Total Under 18          124           319
# 10                Parent of a kid 18 or older           58           162
# 11                                      Total          182           481
#
# ...

# %%
df4.head() # will show only first 5 data
# Out:
#                                         Age  0_to_1_hour  2_to_3_hours  \
# 0  Parent of a kid Younger than 5 years old           25            51
# 1        Parent of a kid 5 to 12 years old            19            47
# 2        Parent of a kid 13 to 17 years old            8            38
# 3                            Total Under 18           52           136
# 4              Parent of a kid 18 or older            63            77
#
#    4_to_5_hours  6_to_7_hours  8_to_9_hours  9_or_more_hours  total condition
# 0            45            32            11               14    178     covid
# 1            94            63            34               30    287     covid
# 2            71            57            39               36    249     covid
# 3           210           152            84               80    714     covid
# 4            91            67            41               42    381     covid

# %%
df4.tail() # will show only last 5 data
# Out:
#                                    Age  0_to_1_hour  2_to_3_hours  \
# 7   Parent of a kid 5 to 12 years old            53           133
# 8   Parent of a kid 13 to 17 years old           21           110
# 9                       Total Under 18          124           319
# 10         Parent of a kid 18 or older           58           162
# 11                               Total          182           481
#
#     4_to_5_hours  6_to_7_hours  8_to_9_hours  9_or_more_hours  total condition
# 7             59            27             5                8    285       pre
# 8             74            15            13               17    250       pre
# 9            163            55            21               32    714       pre
# 10            88            24            16               32    380       pre
# 11           251            79            37               64   1094       pre

# %%
df4.values
# Out:
# array([['Parent of a kid Younger than 5 years old', 25, 51, 45, 32, 11,
#         14, 178, 'covid'],
#        ['Parent of a kid 5 to 12 years old ', 19, 47, 94, 63, 34, 30,
#         287, 'covid'],
#        ['Parent of a kid 13 to 17 years old', 8, 38, 71, 57, 39, 36, 249,
#         'covid'],
#        ['Total Under 18', 52, 136, 210, 152, 84, 80, 714, 'covid'],
#        ['Parent of a kid 18 or older ', 63, 77, 91, 67, 41, 42, 381,
#         'covid'],
#        ['Total', 115, 213, 301, 219, 125, 122, 1095, 'covid'],
#        ['Parent of a kid Younger than 5 years old ', 50, 76, 30, 13, 3,
#         7, 179, 'pre'],
#        ['Parent of a kid 5 to 12 years old ', 53, 133, 59, 27, 5, 8, 285,
#         'pre'],
#        ['Parent of a kid 13 to 17 years old', 21, 110, 74, 15, 13, 17,
#         250, 'pre'],
#        ['Total Under 18', 124, 319, 163, 55, 21, 32, 714, 'pre'],
#        ['Parent of a kid 18 or older', 58, 162, 88, 24, 16, 32, 380,
#         'pre'],
# ...

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df4.columns
# Out:
# Index(['Age', '0_to_1_hour', '2_to_3_hours', '4_to_5_hours', '6_to_7_hours',
#        '8_to_9_hours', '9_or_more_hours', 'total', 'condition'],
#       dtype='object')

# %%
df4['Age']
# Out:
# 0      Parent of a kid Younger than 5 years old
# 1            Parent of a kid 5 to 12 years old
# 2            Parent of a kid 13 to 17 years old
# 3                                Total Under 18
# 4                  Parent of a kid 18 or older
# 5                                         Total
# 6     Parent of a kid Younger than 5 years old
# 7            Parent of a kid 5 to 12 years old
# 8            Parent of a kid 13 to 17 years old
# 9                                Total Under 18
# 10                  Parent of a kid 18 or older
# 11                                        Total
# Name: Age, dtype: object

# %%
df4[['Age','condition']].head()
# Out:
#                                         Age condition
# 0  Parent of a kid Younger than 5 years old     covid
# 1        Parent of a kid 5 to 12 years old      covid
# 2        Parent of a kid 13 to 17 years old     covid
# 3                            Total Under 18     covid
# 4              Parent of a kid 18 or older      covid

# %%
df4['Age'].sort_values
df4
# Out:
#                                           Age  0_to_1_hour  2_to_3_hours  \
# 0    Parent of a kid Younger than 5 years old           25            51
# 1          Parent of a kid 5 to 12 years old            19            47
# 2          Parent of a kid 13 to 17 years old            8            38
# 3                              Total Under 18           52           136
# 4                Parent of a kid 18 or older            63            77
# 5                                       Total          115           213
# 6   Parent of a kid Younger than 5 years old            50            76
# 7          Parent of a kid 5 to 12 years old            53           133
# 8          Parent of a kid 13 to 17 years old           21           110
# 9                              Total Under 18          124           319
# 10                Parent of a kid 18 or older           58           162
# 11                                      Total          182           481
#
# ...

# %%
df4.sort_values('2_to_3_hours', ascending=False)
# Out:
#                                           Age  0_to_1_hour  2_to_3_hours  \
# 11                                      Total          182           481
# 9                              Total Under 18          124           319
# 5                                       Total          115           213
# 10                Parent of a kid 18 or older           58           162
# 3                              Total Under 18           52           136
# 7          Parent of a kid 5 to 12 years old            53           133
# 8          Parent of a kid 13 to 17 years old           21           110
# 4                Parent of a kid 18 or older            63            77
# 6   Parent of a kid Younger than 5 years old            50            76
# 0    Parent of a kid Younger than 5 years old           25            51
# 1          Parent of a kid 5 to 12 years old            19            47
# 2          Parent of a kid 13 to 17 years old            8            38
#
# ...

# %%
df4['2_to_3_hours'] >100
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# Name: 2_to_3_hours, dtype: bool

# %%
df4[df4['2_to_3_hours'] >100]
# Out:
#                                    Age  0_to_1_hour  2_to_3_hours  \
# 3                       Total Under 18           52           136
# 5                                Total          115           213
# 7   Parent of a kid 5 to 12 years old            53           133
# 8   Parent of a kid 13 to 17 years old           21           110
# 9                       Total Under 18          124           319
# 10         Parent of a kid 18 or older           58           162
# 11                               Total          182           481
#
#     4_to_5_hours  6_to_7_hours  8_to_9_hours  9_or_more_hours  total condition
# 3            210           152            84               80    714     covid
# 5            301           219           125              122   1095     covid
# 7             59            27             5                8    285       pre
# 8             74            15            13               17    250       pre
# ...

# %%
df4[df4['Age'] =='Parent of a kid 18 or older']
# Out:
#                             Age  0_to_1_hour  2_to_3_hours  4_to_5_hours  \
# 10  Parent of a kid 18 or older           58           162            88
#
#     6_to_7_hours  8_to_9_hours  9_or_more_hours  total condition
# 10            24            16               32    380       pre

# %%
df4[(df4['Age'] =='Parent of a kid 18 or older')  | (df4['2_to_3_hours'] == 319)]
# Out:
#                             Age  0_to_1_hour  2_to_3_hours  4_to_5_hours  \
# 9                Total Under 18          124           319           163
# 10  Parent of a kid 18 or older           58           162            88
#
#     6_to_7_hours  8_to_9_hours  9_or_more_hours  total condition
# 9             55            21               32    714       pre
# 10            24            16               32    380       pre
